# %% [markdown]
# # Example 2

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

import stuff

x = np.linspace(-1.1, 1.1, 10)
y = [stuff.compute(x_i) for x_i in x]

plt.figure(1, figsize=(12, 6))
plt.suptitle("Stuff's Example 2")
plt.subplot(111)
_ = plt.plot(x, y, "ko-")
